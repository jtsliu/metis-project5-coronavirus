# %%
import pandas as pd
import geopy
import geopandas
import folium
from folium.plugins import FastMarkerCluster

# %%
confirmed_df = pd.read_csv('COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv')
deaths_df = pd.read_csv('COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Deaths.csv')
recovered_df = pd.read_csv('COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Recovered.csv')

# %%
current_df = pd.read_csv('COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-12-2020.csv')

# %%
current_df
# Out:
#     Province/State                  Country/Region          Last Update  \
# 0            Hubei                           China  2020-03-12T09:53:06
# 1              NaN                           Italy  2020-03-11T21:33:02
# 2              NaN                            Iran  2020-03-12T11:13:27
# 3              NaN                    Korea, South  2020-03-12T05:13:02
# 4           France                          France  2020-03-11T22:53:03
# ..             ...                             ...                  ...
# 213         Alaska                              US  2020-03-10T02:33:04
# 214          Idaho                              US  2020-03-10T02:33:04
# 215          Maine                              US  2020-03-10T02:33:04
# 216  West Virginia                              US  2020-03-10T02:33:04
# 217            NaN  occupied Palestinian territory  2020-03-11T20:53:02
#
#      Confirmed  Deaths  Recovered  Latitude  Longitude
# ...

# %%
world_map = folium.Map(
    min_zoom=1,
    tiles='cartodbpositron'
)
current_df.apply(lambda row:folium.CircleMarker(location=[row["Latitude"], row["Longitude"]],
                                                popup=f"{row['Province/State']} \n \
                                                Country: {row['Country/Region']}\n \
                                                Confirmed: {row['Confirmed']}   \n \
                                                Deaths: {row['Deaths']}         \n \
                                                Recovered: {row['Recovered']}",
                                                radius=(row['Confirmed']/current_df.Confirmed.sum())*50,
                                                color='crimson',
                                                fill=True,
                                                fill_color='crimson'
                                               ).add_to(world_map), axis=1)

# for i in range(0,len(current_df)):
#     folium.CircleMarker(
#       location=[current_df.iloc[i]['Latitude'], current_df.iloc[i]['Longitude']],
#       popup=current_df.iloc[i]['Country/Region'],
#       radius=current_df.iloc[i]['Confirmed']*10000,
#       color='crimson',
#       fill=True,
#       fill_color='crimson'
#     ).add_to(world_map)


# FastMarkerCluster(data=list(zip(current_df['Latitude'].values, current_df['Longitude'].values))).add_to(world_map)
# folium.LayerControl().add_to(world_map)

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
confirmed_df[confirmed_df['Country/Region'] == 'US']
# Out:
#        Province/State Country/Region      Lat      Long  1/22/20  1/23/20  \
# 100        Washington             US  47.4009 -121.4905        0        0
# 101          New York             US  42.1657  -74.9481        0        0
# 102        California             US  36.1162 -119.6816        0        0
# 103     Massachusetts             US  42.2302  -71.5301        0        0
# 104  Diamond Princess             US  35.4437  139.6380        0        0
# ..                ...            ...      ...       ...      ...      ...
# 399       Socorro, NM             US  33.8837 -106.7235        0        0
# 400    Bernalillo, NM             US  35.0178 -106.6291        0        0
# 401       Oakland, MI             US  42.5922  -83.3362        0        0
# 402         Wayne, MI             US  42.2791  -83.3362        0        0
# 403    New Castle, DE             US  39.5393  -75.6674        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  3/3/20  3/4/20  3/5/20  3/6/20  \
# ...
